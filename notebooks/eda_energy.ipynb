# %%
# Importar librerías para análisis de datos
import pandas as pd
import numpy as np

# %%
# URL RAW del dataset en GitHub
url = "https://raw.githubusercontent.com/MrAndels/energyiq/refs/heads/main/data/raw/energy_dataset_reducido.csv"

# Cargar dataset desde GitHub
df = pd.read_csv(
    url,
    
    # Separador de columnas
    sep=";",
    
    # Evita problemas de memoria
    low_memory=False
)

# %%
# ==========================================
# ESTRUCTURA GENERAL DEL DATASET
# ==========================================

# Mostrar primeras 5 filas
print("Primeras 5 filas:")
print(df.head())

# Mostrar dimensiones del dataset
print("\nDimensiones del dataset:")
print(df.shape)

# Mostrar nombres de columnas
print("\nColumnas del dataset:")
print(df.columns)

# Mostrar información general
print("\nInformación del dataset:")
print(df.info())

# Mostrar memoria utilizada
print("\nUso de memoria:")
print(df.memory_usage(deep=True))
# Out:
# Primeras 5 filas:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0
#
# Dimensiones del dataset:
# (1600000, 9)
#
# Columnas del dataset:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2',
#        'Sub_metering_3'],
#       dtype='str')
#
# Información del dataset:
# <class 'pandas.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Date                   1600000 non-null  str
#  1   Time                   1600000 non-null  str
#  2   Global_active_power    1600000 non-null  str
#  3   Global_reactive_power  1600000 non-null  str
#  4   Voltage                1600000 non-null  str
#  5   Global_intensity       1600000 non-null  str
#  6   Sub_metering_1         1600000 non-null  str
#  7   Sub_metering_2         1600000 non-null  str
#  8   Sub_metering_3         1591650 non-null  float64
# dtypes: float64(1), str(8)
# memory usage: 184.7 MB
# None
#
# Uso de memoria:
# Index                         132
# Date                     27152640
# Time                     25600000
# Global_active_power      20766610
# Global_reactive_power    20766600
# Voltage                  23949900
# Global_intensity         20955436
# Sub_metering_1           20815300
# Sub_metering_2           20814464
# Sub_metering_3           12800000
# dtype: int64

# %%
# ==========================================
# TIPOS DE VARIABLES
# ==========================================

# Mostrar tipos de datos de cada columna
print("Tipos de datos:")
print(df.dtypes)

# Contar cantidad de tipos de variables
print("\nCantidad de tipos de datos:")
print(df.dtypes.value_counts())

# Mostrar columnas tipo texto
print("\nColumnas tipo texto:")
print(df.select_dtypes(include="object").columns)

# Mostrar columnas numéricas
print("\nColumnas numéricas:")
print(df.select_dtypes(include=["float64", "int64"]).columns)
# Out:
# Tipos de datos:
# Date                         str
# Time                         str
# Global_active_power          str
# Global_reactive_power        str
# Voltage                      str
# Global_intensity             str
# Sub_metering_1               str
# Sub_metering_2               str
# Sub_metering_3           float64
# dtype: object
#
# Cantidad de tipos de datos:
# str        8
# float64    1
# Name: count, dtype: int64
#
# Columnas tipo texto:
# Index(['Date', 'Time', 'Global_active_power', 'Global_reactive_power',
#        'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2'],
#       dtype='str')
#
# Columnas numéricas:
# Index(['Sub_metering_3'], dtype='str')
# C:\Users\Andre\AppData\Local\Temp\ipykernel_2180\1615057456.py:15: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   print(df.select_dtypes(include="object").columns)

# %%
# ==========================================
# VALORES NULOS
# ==========================================

# Contar valores nulos por columna
print("Valores nulos por columna:")
print(df.isnull().sum())

# Calcular porcentaje de valores nulos
print("\nPorcentaje de valores nulos:")

# Mostrar porcentaje por columna
print((df.isnull().sum() / len(df)) * 100)
# Out:
# Valores nulos por columna:
# Date                        0
# Time                        0
# Global_active_power         0
# Global_reactive_power       0
# Voltage                     0
# Global_intensity            0
# Sub_metering_1              0
# Sub_metering_2              0
# Sub_metering_3           8350
# dtype: int64
#
# Porcentaje de valores nulos:
# Date                     0.000000
# Time                     0.000000
# Global_active_power      0.000000
# Global_reactive_power    0.000000
# Voltage                  0.000000
# Global_intensity         0.000000
# Sub_metering_1           0.000000
# Sub_metering_2           0.000000
# Sub_metering_3           0.521875
# dtype: float64

# %%
# ==========================================
# ESTADÍSTICAS Y DISTRIBUCIÓN DE VARIABLES
# ==========================================

# Mostrar estadísticas descriptivas
print("Resumen estadístico del dataset:")

# Analizar variables numéricas
print(df.describe(include="all"))
# Out:
# Resumen estadístico del dataset:
#               Date      Time Global_active_power Global_reactive_power  \
# count      1600000   1600000             1600000               1600000
# unique        1112      1440                4156                   517
# top     17/12/2006  17:24:00               0.218                 0.000
# freq          1440      1112                9206                388206
# mean           NaN       NaN                 NaN                   NaN
# std            NaN       NaN                 NaN                   NaN
# min            NaN       NaN                 NaN                   NaN
# 25%            NaN       NaN                 NaN                   NaN
# 50%            NaN       NaN                 NaN                   NaN
# 75%            NaN       NaN                 NaN                   NaN
# max            NaN       NaN                 NaN                   NaN
#
#         Voltage Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3
# count   1600000          1600000        1600000        1600000    1.591650e+06
# unique     2834              221             84             80             NaN
# top           ?            1.000          0.000          0.000             NaN
# freq       8350           135801        1459082        1136281             NaN
# mean        NaN              NaN            NaN            NaN    6.230947e+00
# std         NaN              NaN            NaN            NaN    8.346246e+00
# min         NaN              NaN            NaN            NaN    0.000000e+00
# 25%         NaN              NaN            NaN            NaN    0.000000e+00
# 50%         NaN              NaN            NaN            NaN    1.000000e+00
# 75%         NaN              NaN            NaN            NaN    1.700000e+01
# max         NaN              NaN            NaN            NaN    3.100000e+01

# %%
# ==========================================
# DUPLICADOS E INCONSISTENCIAS
# ==========================================

# Contar filas duplicadas
duplicados = df.duplicated().sum()

# Mostrar cantidad de duplicados
print("Cantidad de filas duplicadas:")
print(duplicados)

# Mostrar primeras filas duplicadas
print("\nPrimeras filas duplicadas:")

# Filtrar registros duplicados
print(df[df.duplicated()].head())
# Out:
# Cantidad de filas duplicadas:
# 0
#
# Primeras filas duplicadas:
# Empty DataFrame
# Columns: [Date, Time, Global_active_power, Global_reactive_power, Voltage, Global_intensity, Sub_metering_1, Sub_metering_2, Sub_metering_3]
# Index: []

# %%
# ==========================================
# CORRELACIONES ENTRE VARIABLES
# ==========================================

# Lista de columnas numéricas
columnas_numericas = [
    "Global_active_power",
    "Global_reactive_power",
    "Voltage",
    "Global_intensity",
    "Sub_metering_1",
    "Sub_metering_2",
    "Sub_metering_3"
]

# Convertir columnas a tipo numérico
for columna in columnas_numericas:
    
    # Convertir texto a números
    df[columna] = pd.to_numeric(
        df[columna],
        
        # Convertir errores en NaN
        errors="coerce"
    )

# Calcular correlaciones
correlaciones = df[columnas_numericas].corr()

# Mostrar matriz de correlaciones
print("Correlaciones entre variables:")
print(correlaciones)
# Out:
# Correlaciones entre variables:
#                        Global_active_power  Global_reactive_power   Voltage  \
# Global_active_power               1.000000               0.248286 -0.397417
# Global_reactive_power             0.248286               1.000000 -0.115010
# Voltage                          -0.397417              -0.115010  1.000000
# Global_intensity                  0.998952               0.266628 -0.408662
# Sub_metering_1                    0.484572               0.135046 -0.195742
# Sub_metering_2                    0.441136               0.141996 -0.171441
# Sub_metering_3                    0.628683               0.080614 -0.273408
#
#                        Global_intensity  Sub_metering_1  Sub_metering_2  \
# Global_active_power            0.998952        0.484572        0.441136
# Global_reactive_power          0.266628        0.135046        0.141996
# Voltage                       -0.408662       -0.195742       -0.171441
# Global_intensity               1.000000        0.488488        0.447075
# Sub_metering_1                 0.488488        1.000000        0.058524
# Sub_metering_2                 0.447075        0.058524        1.000000
# Sub_metering_3                 0.617209        0.107049        0.086984
#
#                        Sub_metering_3
# Global_active_power          0.628683
# Global_reactive_power        0.080614
# Voltage                     -0.273408
# Global_intensity             0.617209
# Sub_metering_1               0.107049
# Sub_metering_2               0.086984
# Sub_metering_3               1.000000
